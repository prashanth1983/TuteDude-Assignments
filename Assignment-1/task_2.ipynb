# %% [markdown]
# ### Set

# %%
products = ["xps-laptop", "inspiron-laptop", "gaming-latop", "alienware-laptop","chromebook", "workstation-laptop"]
categories = ["premium", "budget", "gaming", "student", "business", "workstation"]

categories_set = set(categories)
print("Categories Set:", categories_set)

# Adding 'ultrabook' category to the set
categories_set.add("ultrabook")
# Adding 'ultrabook' category to the set but it ignores duplicates
categories_set.add("ultrabook")

print("After adding 'ultrabook':", categories_set)

print("business" in categories_set)  # Check if 'business' is in the set
print(len(categories_set))  # Print the set and its length
# Out:
# Categories Set: {'workstation', 'student', 'gaming', 'premium', 'budget', 'business'}
# After adding 'ultrabook': {'ultrabook', 'workstation', 'student', 'gaming', 'premium', 'budget', 'business'}
# True
# 7
